# %%
import pandas as pd 
     
data = pd.read_csv("C:/Users/CSE- LAB-123/Desktop/ml/car-mpg.csv")
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#       mpg  cyl   disp   hp    wt   acc  yr  origin  car_type  \
# 0    18.0    8  307.0  130  3504  12.0  70       1         0
# 1    15.0    8  350.0  165  3693  11.5  70       1         0
# 2    18.0    8  318.0  150  3436  11.0  70       1         0
# 3    16.0    8  304.0  150  3433  12.0  70       1         0
# 4    17.0    8  302.0  140  3449  10.5  70       1         0
# ..    ...  ...    ...  ...   ...   ...  ..     ...       ...
# 393  27.0    4  140.0   86  2790  15.6  82       1         1
# 394  44.0    4   97.0   52  2130  24.6  82       2         1
# 395  32.0    4  135.0   84  2295  11.6  82       1         1
# 396  28.0    4  120.0   79  2625  18.6  82       1         1
# 397  31.0    4  119.0   82  2720  19.4  82       1         1
#
#                       car_name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# ...

# %%
data.shape
# Out:
# (398, 10)

# %%
 nrow_count = data.shape[0]

# %%
print (nrow_count)
# Out:
# 398

# %%
ncol_count = data.shape[1]

# %%
print(ncol_count)
# Out:
# 10

# %%
data.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'wt', 'acc', 'yr', 'origin', 'car_type',
#        'car_name'],
#       dtype='object')

# %%
list(data.columns.values)
# Out:
# ['mpg',
#  'cyl',
#  'disp',
#  'hp',
#  'wt',
#  'acc',
#  'yr',
#  'origin',
#  'car_type',
#  'car_name']

# %%
data.columns = ['miles per_gallon', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'origin', 'car type','car name']

# %%
data.rename(columns = {'displacements':'disp'},inplace = True)

# %%
data.head()
# Out:
#    miles per_gallon  cylinders  displacement horsepower  weight  acceleration  \
# 0              18.0          8         307.0        130    3504          12.0
# 1              15.0          8         350.0        165    3693          11.5
# 2              18.0          8         318.0        150    3436          11.0
# 3              16.0          8         304.0        150    3433          12.0
# 4              17.0          8         302.0        140    3449          10.5
#
#    model year  origin  car type                   car name
# 0          70       1         0  chevrolet chevelle malibu
# 1          70       1         0          buick skylark 320
# 2          70       1         0         plymouth satellite
# 3          70       1         0              amc rebel sst
# 4          70       1         0                ford torino

# %%
data.head(3)
# Out:
#    miles per_gallon  cylinders  displacement horsepower  weight  acceleration  \
# 0              18.0          8         307.0        130    3504          12.0
# 1              15.0          8         350.0        165    3693          11.5
# 2              18.0          8         318.0        150    3436          11.0
#
#    model year  origin  car type                   car name
# 0          70       1         0  chevrolet chevelle malibu
# 1          70       1         0          buick skylark 320
# 2          70       1         0         plymouth satellite

# %%
data.tail()
# Out:
#      miles per_gallon  cylinders  displacement horsepower  weight  \
# 393              27.0          4         140.0         86    2790
# 394              44.0          4          97.0         52    2130
# 395              32.0          4         135.0         84    2295
# 396              28.0          4         120.0         79    2625
# 397              31.0          4         119.0         82    2720
#
#      acceleration  model year  origin  car type         car name
# 393          15.6          82       1         1  ford mustang gl
# 394          24.6          82       2         1        vw pickup
# 395          11.6          82       1         1    dodge rampage
# 396          18.6          82       1         1      ford ranger
# 397          19.4          82       1         1       chevy s-10

# %%
data.tail(3)
# Out:
#      miles per_gallon  cylinders  displacement horsepower  weight  \
# 395              32.0          4         135.0         84    2295
# 396              28.0          4         120.0         79    2625
# 397              31.0          4         119.0         82    2720
#
#      acceleration  model year  origin  car type       car name
# 395          11.6          82       1         1  dodge rampage
# 396          18.6          82       1         1    ford ranger
# 397          19.4          82       1         1     chevy s-10

# %%
data.at[200,'cylinders']
# Out:
# 6

# %%
data_cyl = data.loc[: , "car name"]

# %%
data_cyl.head()
# Out:
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# Name: car name, dtype: object

# %%
data_cyl = data[["miles per_gallon", "origin", "car name"]]

# %%
data_cyl.head()
# Out:
#    miles per_gallon  origin                   car name
# 0              18.0       1  chevrolet chevelle malibu
# 1              15.0       1          buick skylark 320
# 2              18.0       1         plymouth satellite
# 3              16.0       1              amc rebel sst
# 4              17.0       1                ford torino

# %%
data[1:3]
# Out:
#    miles per_gallon  cylinders  displacement horsepower  weight  acceleration  \
# 1              15.0          8         350.0        165    3693          11.5
# 2              18.0          8         318.0        150    3436          11.0
#
#    model year  origin  car type            car name
# 1          70       1         0   buick skylark 320
# 2          70       1         0  plymouth satellite

# %%
data.loc[1, : ]
# Out:
# miles per_gallon                 15.0
# cylinders                           8
# displacement                    350.0
# horsepower                        165
# weight                           3693
# acceleration                     11.5
# model year                         70
# origin                              1
# car type                            0
# car name            buick skylark 320
# Name: 1, dtype: object

# %%
data.loc[2, : ]
# Out:
# miles per_gallon                  18.0
# cylinders                            8
# displacement                     318.0
# horsepower                         150
# weight                            3436
# acceleration                      11.0
# model year                          70
# origin                               1
# car type                             0
# car name            plymouth satellite
# Name: 2, dtype: object

# %%
data1 = data[0:2]

# %%
data1.head()
# Out:
#    miles per_gallon  cylinders  displacement horsepower  weight  acceleration  \
# 0              18.0          8         307.0        130    3504          12.0
# 1              15.0          8         350.0        165    3693          11.5
#
#    model year  origin  car type                   car name
# 0          70       1         0  chevrolet chevelle malibu
# 1          70       1         0          buick skylark 320

# %%
data2 = data[3:5]

# %%
data2.head()
# Out:
#    miles per_gallon  cylinders  displacement horsepower  weight  acceleration  \
# 3              16.0          8         304.0        150    3433          12.0
# 4              17.0          8         302.0        140    3449          10.5
#
#    model year  origin  car type       car name
# 3          70       1         0  amc rebel sst
# 4          70       1         0    ford torino

# %%
data3 = data1.append(data2, ignore_index=True)

# %%
data3.head()
# Out:
#    miles per_gallon  cylinders  displacement horsepower  weight  acceleration  \
# 0              18.0          8         307.0        130    3504          12.0
# 1              15.0          8         350.0        165    3693          11.5
# 2              16.0          8         304.0        150    3433          12.0
# 3              17.0          8         302.0        140    3449          10.5
#
#    model year  origin  car type                   car name
# 0          70       1         0  chevrolet chevelle malibu
# 1          70       1         0          buick skylark 320
# 2          70       1         0              amc rebel sst
# 3          70       1         0                ford torino

# %%
data3.shape
# Out:
# (4, 10)

# %%
# Bind sets of columns of dataframes:
data1 = data["miles per_gallon"]

# %%
data1.head()
# Out:
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# Name: miles per_gallon, dtype: float64

# %%
data2 = data["car name"]

# %%
data2.head()
# Out:
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# Name: car name, dtype: object

# %%
data3 = pd.concat([data1.reset_index(drop=True), data2], axis=1)

# %%
data3.head()
# Out:
#    miles per_gallon                   car name
# 0              18.0  chevrolet chevelle malibu
# 1              15.0          buick skylark 320
# 2              18.0         plymouth satellite
# 3              16.0              amc rebel sst
# 4              17.0                ford torino

# %%
data3.to_csv('data3.csv')

# %%
data3.to_csv('data.3.csv', index=False)

# %%
data = data.drop_duplicates ()

# %%
# Remove all rows where values of all columns are NaN'
data.dropna (axis=0, how='all')
# Out:
#      miles per_gallon  cylinders  displacement horsepower  weight  \
# 0                18.0          8         307.0        130    3504
# 1                15.0          8         350.0        165    3693
# 2                18.0          8         318.0        150    3436
# 3                16.0          8         304.0        150    3433
# 4                17.0          8         302.0        140    3449
# ..                ...        ...           ...        ...     ...
# 393              27.0          4         140.0         86    2790
# 394              44.0          4          97.0         52    2130
# 395              32.0          4         135.0         84    2295
# 396              28.0          4         120.0         79    2625
# 397              31.0          4         119.0         82    2720
#
#      acceleration  model year  origin  car type                   car name
# 0            12.0          70       1         0  chevrolet chevelle malibu
# ...

# %%
  # Remove all columns where values of all rows are 'NaN' 
    data.dropna (axis=1, how='all')
# Out:
#      miles per_gallon  cylinders  displacement horsepower  weight  \
# 0                18.0          8         307.0        130    3504
# 1                15.0          8         350.0        165    3693
# 2                18.0          8         318.0        150    3436
# 3                16.0          8         304.0        150    3433
# 4                17.0          8         302.0        140    3449
# ..                ...        ...           ...        ...     ...
# 393              27.0          4         140.0         86    2790
# 394              44.0          4          97.0         52    2130
# 395              32.0          4         135.0         84    2295
# 396              28.0          4         120.0         79    2625
# 397              31.0          4         119.0         82    2720
#
#      acceleration  model year  origin  car type                   car name
# 0            12.0          70       1         0  chevrolet chevelle malibu
# ...

# %%
# Remove all rows where value of any column is 'NaN' 
data.dropna (axis=0, how='any')
# Out:
#      miles per_gallon  cylinders  displacement horsepower  weight  \
# 0                18.0          8         307.0        130    3504
# 1                15.0          8         350.0        165    3693
# 2                18.0          8         318.0        150    3436
# 3                16.0          8         304.0        150    3433
# 4                17.0          8         302.0        140    3449
# ..                ...        ...           ...        ...     ...
# 393              27.0          4         140.0         86    2790
# 394              44.0          4          97.0         52    2130
# 395              32.0          4         135.0         84    2295
# 396              28.0          4         120.0         79    2625
# 397              31.0          4         119.0         82    2720
#
#      acceleration  model year  origin  car type                   car name
# 0            12.0          70       1         0  chevrolet chevelle malibu
# ...

# %%
# Remove all col umns where value of any row is 'NaN'
data.dropna (axis=1, how='any')
# Out:
#      miles per_gallon  cylinders  displacement horsepower  weight  \
# 0                18.0          8         307.0        130    3504
# 1                15.0          8         350.0        165    3693
# 2                18.0          8         318.0        150    3436
# 3                16.0          8         304.0        150    3433
# 4                17.0          8         302.0        140    3449
# ..                ...        ...           ...        ...     ...
# 393              27.0          4         140.0         86    2790
# 394              44.0          4          97.0         52    2130
# 395              32.0          4         135.0         84    2295
# 396              28.0          4         120.0         79    2625
# 397              31.0          4         119.0         82    2720
#
#      acceleration  model year  origin  car type                   car name
# 0            12.0          70       1         0  chevrolet chevelle malibu
# ...
